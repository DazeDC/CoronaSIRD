# %%
import pandas as pd
import copy
from matplotlib import pyplot as plt
import numpy as np

# %%
# Deaths
total_nv_deaths_number = pd.read_csv("../novaccine/results/corona_n_dead{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_deaths_number = pd.read_csv("../youngerfirstvaccine/results/corona_n_dead{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_deaths_number = pd.read_csv("../olderfirstvaccine/results/corona_n_dead{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_deaths_number = pd.read_csv("../randvaccine/results/corona_n_dead{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

# Recoveries
total_nv_recoveries_number = pd.read_csv("../novaccine/results/corona_n_recovered{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_recoveries_number = pd.read_csv("../youngerfirstvaccine/results/corona_n_recovered{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_recoveries_number = pd.read_csv("../olderfirstvaccine/results/corona_n_recovered{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_recoveries_number = pd.read_csv("../randvaccine/results/corona_n_recovered{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

# Infections Totals
total_nv_infections_tot_number = pd.read_csv("../novaccine/results/corona_#I_COUNTER__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_tot_number = pd.read_csv("../youngerfirstvaccine/results/corona_#I_COUNTER__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_tot_number = pd.read_csv("../olderfirstvaccine/results/corona_#I_COUNTER__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_tot_number = pd.read_csv("../randvaccine/results/corona_#I_COUNTER__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

# Infections
total_nv_infections_number = pd.read_csv("../novaccine/results/corona_n_infected{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number = pd.read_csv("../youngerfirstvaccine/results/corona_n_infected{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number = pd.read_csv("../olderfirstvaccine/results/corona_n_infected{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number = pd.read_csv("../randvaccine/results/corona_n_infected{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

# Vaccinations
total_yfv_vaccinations_number = pd.read_csv("../youngerfirstvaccine/results/corona_#V__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_vaccinations_number = pd.read_csv("../olderfirstvaccine/results/corona_#V__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_vaccinations_number = pd.read_csv("../randvaccine/results/corona_#V__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

print("********** Deaths *************")
print(f"NV total: {total_nv_deaths_number['mean'].values[-1]}, std dev: {total_nv_deaths_number['std_dev'].values[-1]}")
print(f"YFV total: {total_yfv_deaths_number['mean'].values[-1]}, std dev: {total_yfv_deaths_number['std_dev'].values[-1]}")
print(f"OFV total: {total_ofv_deaths_number['mean'].values[-1]}, std dev: {total_ofv_deaths_number['std_dev'].values[-1]}")
print(f"RV total: {total_rv_deaths_number['mean'].values[-1]}, std dev: {total_rv_deaths_number['std_dev'].values[-1]}")

print("********** Recoveries *************")
print(f"NV total: {total_nv_recoveries_number['mean'].values[-1]}, std dev: {total_nv_recoveries_number['std_dev'].values[-1]}")
print(f"YFV total: {total_yfv_recoveries_number['mean'].values[-1]}, std dev: {total_yfv_recoveries_number['std_dev'].values[-1]}")
print(f"OFV total: {total_ofv_recoveries_number['mean'].values[-1]}, std dev: {total_ofv_recoveries_number['std_dev'].values[-1]}")
print(f"RV total: {total_rv_recoveries_number['mean'].values[-1]}, std dev: {total_rv_recoveries_number['std_dev'].values[-1]}")

print("********** Infections Totals *************")
print(f"NV total: {total_nv_infections_tot_number['mean'].values[-1]}, std dev: {total_nv_infections_tot_number['std_dev'].values[-1]}")
print(f"YFV total: {total_yfv_infections_tot_number['mean'].values[-1]}, std dev: {total_yfv_infections_tot_number['std_dev'].values[-1]}")
print(f"OFV total: {total_ofv_infections_tot_number['mean'].values[-1]}, std dev: {total_ofv_infections_tot_number['std_dev'].values[-1]}")
print(f"RV total: {total_rv_infections_tot_number['mean'].values[-1]}, std dev: {total_rv_infections_tot_number['std_dev'].values[-1]}")

print("********** Infections Peak *************")
nv_inf_max = total_nv_infections_number['mean'].idxmax()
print(f"NV total: {total_nv_infections_number['mean'].values[nv_inf_max]}, std dev: {total_nv_infections_number['std_dev'].values[nv_inf_max]}, t.u.: {nv_inf_max}")
yfv_inf_max = total_yfv_infections_number['mean'].idxmax()
print(f"YFV total: {total_yfv_infections_number['mean'].values[yfv_inf_max]}, std dev: {total_yfv_infections_number['std_dev'].values[yfv_inf_max]}, t.u.: {yfv_inf_max}")
ofv_inf_max = total_ofv_infections_number['mean'].idxmax()
print(f"OFV total: {total_ofv_infections_number['mean'].values[ofv_inf_max]}, std dev: {total_ofv_infections_number['std_dev'].values[ofv_inf_max]}, t.u.: {ofv_inf_max}")
rv_inf_max = total_rv_infections_number['mean'].idxmax()
print(f"RV total: {total_rv_infections_number['mean'].values[rv_inf_max]}, std dev: {total_rv_infections_number['std_dev'].values[rv_inf_max]}, t.u.: {rv_inf_max}")


print("********** Vaccinations Totals *************")
print(f"YFV total: {total_yfv_vaccinations_number['mean'].values[-1]}, std dev: {total_yfv_vaccinations_number['std_dev'].values[-1]}")
print(f"OFV total: {total_ofv_vaccinations_number['mean'].values[-1]}, std dev: {total_ofv_vaccinations_number['std_dev'].values[-1]}")
print(f"RV total: {total_rv_vaccinations_number['mean'].values[-1]}, std dev: {total_rv_vaccinations_number['std_dev'].values[-1]}")

# %%
# Infections Per Age Group
total_nv_infections_number0 = pd.read_csv("../novaccine/results/corona_#I[0]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number1 = pd.read_csv("../novaccine/results/corona_#I[1]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number2 = pd.read_csv("../novaccine/results/corona_#I[2]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number3 = pd.read_csv("../novaccine/results/corona_#I[3]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number4 = pd.read_csv("../novaccine/results/corona_#I[4]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number5 = pd.read_csv("../novaccine/results/corona_#I[5]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_nv_infections_number0["mean"], label="< 50", color="blue")
plt.plot(total_nv_infections_number1["mean"], label="50 - 60", color="red")
plt.plot(total_nv_infections_number2["mean"], label="60 - 70", color="orange")
plt.plot(total_nv_infections_number3["mean"], label="70 - 80", color="green")
plt.plot(total_nv_infections_number4["mean"], label="80 - 90", color="purple")
plt.plot(total_nv_infections_number5["mean"], label="> 90", color="black")
# plt.yticks(range(0, 251, 20))
plt.legend()

f.savefig("../total_results/threshold/novaccine_infections_per_age.pdf")

# %%
# Infections Per Age Group
total_yfv_infections_number0 = pd.read_csv("../youngerfirstvaccine/results/corona_#I[0]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number1 = pd.read_csv("../youngerfirstvaccine/results/corona_#I[1]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number2 = pd.read_csv("../youngerfirstvaccine/results/corona_#I[2]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number3 = pd.read_csv("../youngerfirstvaccine/results/corona_#I[3]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number4 = pd.read_csv("../youngerfirstvaccine/results/corona_#I[4]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number5 = pd.read_csv("../youngerfirstvaccine/results/corona_#I[5]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_yfv_infections_number0["mean"], label="< 50", color="blue")
plt.plot(total_yfv_infections_number1["mean"], label="50 - 60", color="red")
plt.plot(total_yfv_infections_number2["mean"], label="60 - 70", color="orange")
plt.plot(total_yfv_infections_number3["mean"], label="70 - 80", color="green")
plt.plot(total_yfv_infections_number4["mean"], label="80 - 90", color="purple")
plt.plot(total_yfv_infections_number5["mean"], label="> 90", color="black")
plt.yticks(range(0, 251, 20))
plt.legend()

f.savefig("../total_results/threshold/youngerfirst_infections_per_age.pdf")

# %%
# Infections Per Age Group
total_ofv_infections_number0 = pd.read_csv("../olderfirstvaccine/results/corona_#I[0]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number1 = pd.read_csv("../olderfirstvaccine/results/corona_#I[1]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number2 = pd.read_csv("../olderfirstvaccine/results/corona_#I[2]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number3 = pd.read_csv("../olderfirstvaccine/results/corona_#I[3]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number4 = pd.read_csv("../olderfirstvaccine/results/corona_#I[4]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number5 = pd.read_csv("../olderfirstvaccine/results/corona_#I[5]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_ofv_infections_number0["mean"], label="< 50", color="blue")
plt.plot(total_ofv_infections_number1["mean"], label="50 - 60", color="red")
plt.plot(total_ofv_infections_number2["mean"], label="60 - 70", color="orange")
plt.plot(total_ofv_infections_number3["mean"], label="70 - 80", color="green")
plt.plot(total_ofv_infections_number4["mean"], label="80 - 90", color="purple")
plt.plot(total_ofv_infections_number5["mean"], label="> 90", color="black")
plt.yticks(range(0, 251, 20))
plt.legend()

f.savefig("../total_results/threshold/olderfirst_infections_per_age.pdf")

# %%
# Infections Per Age Group
total_rv_infections_number0 = pd.read_csv("../randvaccine/results/corona_#I[0]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number1 = pd.read_csv("../randvaccine/results/corona_#I[1]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number2 = pd.read_csv("../randvaccine/results/corona_#I[2]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number3 = pd.read_csv("../randvaccine/results/corona_#I[3]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number4 = pd.read_csv("../randvaccine/results/corona_#I[4]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number5 = pd.read_csv("../randvaccine/results/corona_#I[5]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_rv_infections_number0["mean"], label="< 50", color="blue")
plt.plot(total_rv_infections_number1["mean"], label="50 - 60", color="red")
plt.plot(total_rv_infections_number2["mean"], label="60 - 70", color="orange")
plt.plot(total_rv_infections_number3["mean"], label="70 - 80", color="green")
plt.plot(total_rv_infections_number4["mean"], label="80 - 90", color="purple")
plt.plot(total_rv_infections_number5["mean"], label="> 90", color="black")
plt.yticks(range(0, 251, 20))
plt.legend()

f.savefig("../total_results/threshold/randvacc_infections_per_age.pdf")

# %%
# ****************************************** DEATHS *******************************************

# %%
total_nv_deaths_number = pd.read_csv("../novaccine/results/corona_n_dead{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_deaths_number = pd.read_csv("../youngerfirstvaccine/results/corona_n_dead{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_deaths_number = pd.read_csv("../olderfirstvaccine/results/corona_n_dead{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_deaths_number = pd.read_csv("../randvaccine/results/corona_n_dead{}__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_nv_deaths_number["mean"], label="No Vaccine Deaths", color="blue")
plt.plot(total_yfv_deaths_number["mean"], label="Younger First Vaccine Deaths", color="red")
plt.plot(total_ofv_deaths_number["mean"], label="Older First Vaccine Deaths", color="orange")
plt.plot(total_rv_deaths_number["mean"], label="Random Vaccine Deaths", color="green")
plt.yticks(range(0, 251, 20))
plt.legend()

print(f'NV mean: {total_nv_deaths_number["mean"].values[-1]}')
print(f'NV std: {total_nv_deaths_number["std_dev"].values[-1]}')
print(f'YFV mean: {total_yfv_deaths_number["mean"].values[-1]}')
print(f'YFV std: {total_yfv_deaths_number["std_dev"].values[-1]}')
print(f'OFV mean: {total_ofv_deaths_number["mean"].values[-1]}')
print(f'OFV std: {total_ofv_deaths_number["std_dev"].values[-1]}')
print(f'RV mean: {total_rv_deaths_number["mean"].values[-1]}')
print(f'RV std: {total_rv_deaths_number["std_dev"].values[-1]}')

f.savefig("../total_results/deaths.pdf")

# %%
f = plt.figure()
plt.errorbar(nv_inf_max, total_nv_infections_number['mean'].values[nv_inf_max], fmt='o', label="no vaccine")
plt.errorbar(ofv_inf_max, total_ofv_infections_number['mean'].values[ofv_inf_max], fmt='o', label="older first vaccine")
plt.errorbar(rv_inf_max, total_rv_infections_number['mean'].values[rv_inf_max], fmt='o', label="random vaccine")
plt.errorbar(yfv_inf_max, total_yfv_infections_number['mean'].values[yfv_inf_max], fmt='o', label="younger first vaccine")
plt.xlabel("Time unit when maximum is reached")
plt.ylabel("Maximum number of infected")
plt.legend()

f.savefig("../total_results/maximum_infected.pdf")

# %%
# Infections Per Age Group
total_nv_infections_number0 = pd.read_csv("../novaccine/results/corona_#D[0]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number1 = pd.read_csv("../novaccine/results/corona_#D[1]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number2 = pd.read_csv("../novaccine/results/corona_#D[2]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number3 = pd.read_csv("../novaccine/results/corona_#D[3]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number4 = pd.read_csv("../novaccine/results/corona_#D[4]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_nv_infections_number5 = pd.read_csv("../novaccine/results/corona_#D[5]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_nv_infections_number0["mean"], label="< 50", color="blue")
plt.plot(total_nv_infections_number1["mean"], label="50 - 60", color="red")
plt.plot(total_nv_infections_number2["mean"], label="60 - 70", color="orange")
plt.plot(total_nv_infections_number3["mean"], label="70 - 80", color="green")
plt.plot(total_nv_infections_number4["mean"], label="80 - 90", color="purple")
plt.plot(total_nv_infections_number5["mean"], label="> 90", color="black")
# plt.yticks(range(0, 251, 20))
plt.legend()

f.savefig("../total_results/threshold/novaccine_deaths_per_age.pdf")

# %%
# Infections Per Age Group
total_yfv_infections_number0 = pd.read_csv("../youngerfirstvaccine/results/corona_#D[0]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number1 = pd.read_csv("../youngerfirstvaccine/results/corona_#D[1]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number2 = pd.read_csv("../youngerfirstvaccine/results/corona_#D[2]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number3 = pd.read_csv("../youngerfirstvaccine/results/corona_#D[3]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number4 = pd.read_csv("../youngerfirstvaccine/results/corona_#D[4]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_yfv_infections_number5 = pd.read_csv("../youngerfirstvaccine/results/corona_#D[5]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_yfv_infections_number0["mean"], label="< 50", color="blue")
plt.plot(total_yfv_infections_number1["mean"], label="50 - 60", color="red")
plt.plot(total_yfv_infections_number2["mean"], label="60 - 70", color="orange")
plt.plot(total_yfv_infections_number3["mean"], label="70 - 80", color="green")
plt.plot(total_yfv_infections_number4["mean"], label="80 - 90", color="purple")
plt.plot(total_yfv_infections_number5["mean"], label="> 90", color="black")
plt.legend()

f.savefig("../total_results/threshold/youngerfirst_deaths_per_age.pdf")

# %%
# Infections Per Age Group
total_ofv_infections_number0 = pd.read_csv("../olderfirstvaccine/results/corona_#D[0]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number1 = pd.read_csv("../olderfirstvaccine/results/corona_#D[1]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number2 = pd.read_csv("../olderfirstvaccine/results/corona_#D[2]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number3 = pd.read_csv("../olderfirstvaccine/results/corona_#D[3]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number4 = pd.read_csv("../olderfirstvaccine/results/corona_#D[4]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_ofv_infections_number5 = pd.read_csv("../olderfirstvaccine/results/corona_#D[5]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_ofv_infections_number0["mean"], label="< 50", color="blue")
plt.plot(total_ofv_infections_number1["mean"], label="50 - 60", color="red")
plt.plot(total_ofv_infections_number2["mean"], label="60 - 70", color="orange")
plt.plot(total_ofv_infections_number3["mean"], label="70 - 80", color="green")
plt.plot(total_ofv_infections_number4["mean"], label="80 - 90", color="purple")
plt.plot(total_ofv_infections_number5["mean"], label="> 90", color="black")
plt.legend()

f.savefig("../total_results/threshold/olderfirst_deaths_per_age.pdf")

# %%
# Infections Per Age Group
total_rv_infections_number0 = pd.read_csv("../randvaccine/results/corona_#D[0]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number1 = pd.read_csv("../randvaccine/results/corona_#D[1]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number2 = pd.read_csv("../randvaccine/results/corona_#D[2]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number3 = pd.read_csv("../randvaccine/results/corona_#D[3]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number4 = pd.read_csv("../randvaccine/results/corona_#D[4]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])
total_rv_infections_number5 = pd.read_csv("../randvaccine/results/corona_#D[5]__.csv", sep=";", names=['t.u.', 'mean', 'variance', 'std_dev'])

f = plt.figure()
plt.plot(total_rv_infections_number0["mean"], label="< 50", color="blue")
plt.plot(total_rv_infections_number1["mean"], label="50 - 60", color="red")
plt.plot(total_rv_infections_number2["mean"], label="60 - 70", color="orange")
plt.plot(total_rv_infections_number3["mean"], label="70 - 80", color="green")
plt.plot(total_rv_infections_number4["mean"], label="80 - 90", color="purple")
plt.plot(total_rv_infections_number5["mean"], label="> 90", color="black")
plt.legend()

f.savefig("../total_results/threshold/randvacc_deaths_per_age.pdf")
